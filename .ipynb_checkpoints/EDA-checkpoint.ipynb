# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("synthetic_dataset_30000.csv")

desc_stats = df.describe()

median = df.select_dtypes(include='number').median()

print("📊 Descriptive Statistics:")
print(desc_stats)

print("\n📍 Median values:")
print(median)
# Out:
# 📊 Descriptive Statistics:
#               Price  Number of products sold  Revenue generated  Stock levels  \
# count  30000.000000              30000.00000       30000.000000  30000.000000
# mean     250.881933                501.36510       25013.781967    250.443700
# std      142.969735                288.30337       14430.011909    143.948737
# min        5.000000                  0.00000         100.000000      0.000000
# 25%      127.000000                252.00000       12528.500000    126.750000
# 50%      249.000000                501.00000       24951.500000    251.000000
# 75%      375.000000                750.00000       37522.250000    375.000000
# max      499.000000                999.00000       49998.000000    499.000000
#
#          Lead times  Order quantities  Shipping times  Shipping costs  \
# count  30000.000000      30000.000000    30000.000000    30000.000000
# mean      14.920133         50.050933        6.968367       52.556362
# std        8.349100         28.512707        3.748008       27.426652
# min        1.000000          1.000000        1.000000        5.000000
# 25%        8.000000         25.000000        4.000000       28.837500
# 50%       15.000000         50.000000        7.000000       52.440000
# 75%       22.000000         75.000000       10.000000       76.362500
# max       29.000000         99.000000       13.000000      100.000000
#
#        Production volumes  Manufacturing lead time  Manufacturing costs
# count        30000.000000             30000.000000         30000.000000
# mean          5062.174500                30.035833          5045.721700
# std           2877.967569                17.023410          2860.834398
# min            100.000000                 1.000000           100.000000
# 25%           2551.000000                15.000000          2556.750000
# 50%           5074.500000                30.000000          5060.500000
# 75%           7570.250000                45.000000          7528.250000
# max           9999.000000                59.000000          9999.000000
#
# 📍 Median values:
# Price                        249.00
# Number of products sold      501.00
# Revenue generated          24951.50
# Stock levels                 251.00
# Lead times                    15.00
# Order quantities              50.00
# Shipping times                 7.00
# Shipping costs                52.44
# Production volumes          5074.50
# Manufacturing lead time       30.00
# Manufacturing costs         5060.50
# dtype: float64

# %%
corr = df['Price'].corr(df['Number of products sold'])
print("Correlation Price vs Number of products sold:", corr)
# Out:
# Correlation Price vs Number of products sold: -0.011318363689925106

# %%
plt.hexbin(df['Price'], df['Number of products sold'], gridsize=40, cmap='Blues')
plt.colorbar(label="Number of points")
plt.xlabel("Price")
plt.ylabel("Number of products sold")
plt.title("Hexbin Plot: Price vs Sales")
plt.show()

# %%
corr = df['Lead times'].corr(df['Number of products sold'])
print("Correlation Lead Time vs Units Sold:", corr)
# Out:
# Correlation Lead Time vs Units Sold: 0.0019721944432508996

# %%
plt.hexbin(
    df['Lead times'], 
    df['Number of products sold'], 
    gridsize=40, 
    cmap="Blues"
)
plt.colorbar(label="Count of points")
plt.xlabel("Lead Time")
plt.ylabel("Number of products sold")
plt.title("Hexbin: Lead Time vs Units Sold")
plt.show()

# %%
supplier_shipping = df.groupby('Location')['Shipping costs'].mean()

print("📊 Average Shipping Cost by Supplier Location:")
print(supplier_shipping)
# Out:
# 📊 Average Shipping Cost by Supplier Location:
# Location
# China      52.375270
# Egypt      51.907242
# Germany    52.543925
# India      52.964357
# USA        52.995354
# Name: Shipping costs, dtype: float64

# %%
ax = supplier_shipping.plot(kind='bar', figsize=(10,5), color="lightgreen")
plt.ylabel("Average Shipping Cost")
plt.title("Avg Shipping Cost by Supplier Location (Sorted)")

for i, v in enumerate(supplier_shipping):
    ax.text(i, v + 0.5, round(v,2), ha='center')

plt.show()

# %%
pivot_data = df.pivot_table(
    values="Shipping costs",
    index="Location",
    columns="Shipping carriers",
    aggfunc="mean"
)

plt.figure(figsize=(10,6))
sns.heatmap(pivot_data, annot=True, cmap="YlGnBu", fmt=".1f")
plt.title("Avg Shipping Cost by Location & Carrier")
plt.ylabel("Supplier Location")
plt.xlabel("Shipping Carrier")
plt.show()

# %%
cols = ["Price", "Number of products sold", "Lead times", 
        "Order quantities", "Shipping times", "Shipping costs"]

corr = df[cols].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="Blues", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
